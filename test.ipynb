# %%
import mlflow

# %%
mlflow.set_tracking_uri("http://127.0.0.1:5000/")

# %%
mlflow.set_experiment("Test_Experiment")
with mlflow.start_run():
    mlflow.log_param("param1", 5)
    mlflow.log_metric("metric1", 0.85)
# Out:
# 2026/02/01 13:19:37 INFO mlflow.tracking.fluent: Experiment with name 'Test_Experiment' does not exist. Creating a new experiment.
# 🏃 View run bold-tern-434 at: http://127.0.0.1:5000/#/experiments/1/runs/a3eaeb97556b4b38805f6a0c336e4a33
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
